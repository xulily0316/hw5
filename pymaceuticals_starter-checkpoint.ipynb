# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# -1. Capomulin and Ramicane have the highest numbers of mice per treatment, which means that they could dramatically reducing death as an anti-cancer treatment.
#
# -2. Capomulin is the most effective anti-cancer medication in controling the tumor volume considering the distribution of the Tumer Volums boxplot.
#
# -3. The average tumor volume will increase when the mouse weight increases. The correlation between mouse weight and average tumor volume is 0.84, which shows a positive correlation.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_df=pd.merge(mouse_metadata, study_results, how="outer", on="Mouse ID")
# Display the data table for preview
merged_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
number_of_mice=(len(merged_df["Mouse ID"].value_counts()))
number_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice=merged_df.loc[merged_df.duplicated(subset=["Mouse ID","Timepoint"]),"Mouse ID"].unique()

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mice_df=pd.DataFrame(duplicate_mice)
duplicate_mice_df
# Out:
#       0
# 0  g989

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
new_df=merged_df[merged_df["Mouse ID"].isin(duplicate_mice)==False]

# %%
# Checking the number of mice in the clean DataFrame.
count_new_df=new_df["Mouse ID"].value_counts()
count_mice_number=len(count_new_df)
count_mice_number
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
means = merged_df.groupby("Drug Regimen").mean()["Tumor Volume (mm3)"]
medians = merged_df.groupby("Drug Regimen").median()["Tumor Volume (mm3)"]
variances = merged_df.groupby("Drug Regimen").var()["Tumor Volume (mm3)"]
standards = merged_df.groupby("Drug Regimen").std()["Tumor Volume (mm3)"]
sem = merged_df.groupby("Drug Regimen").sem()["Tumor Volume (mm3)"]
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
summary_sta_1 = pd.DataFrame({"Mean Tumor Volume": means, "Median Tumor Volume":medians, "Tumor Volume Variance":variances, "Tumor Volume Std. Dev.": standards, "Tumor Volume Std. Err.": sem})
summary_sta_1
summary_sta_1.to_csv("SummaryStatistics.csv")

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line.

summary_sta_2 = merged_df.groupby("Drug Regimen")
summary_sta_2 = summary_sta_2.agg(["mean","median","var","std","sem"])["Tumor Volume (mm3)"].dropna()
summary_sta_2
# Out:
# C:\Users\Chloe\AppData\Local\Temp\ipykernel_1448\4039827602.py:6: FutureWarning: ['Mouse ID', 'Sex'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   summary_sta_2 = summary_sta_2.agg(["mean","median","var","std","sem"])["Tumor Volume (mm3)"].dropna()
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
plot_data= merged_df.groupby(["Drug Regimen"]).count()["Mouse ID"] 
plot_df=pd.DataFrame(plot_data)
plot_count= plot_df.plot.bar(legend=False,rot=50)

plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.title("Number of Mice per Treatment")

plt.savefig("BarChat.png")
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
import numpy as np
x_axis = np.arange(len(plot_data))
plot_list=(merged_df.groupby(["Drug Regimen"])["Mouse ID"].count()).tolist()
plt.figure(figsize=(8,5))
plt.bar(x_axis, plot_list, alpha=0.9, align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Capomulin", "Ceftamin", "Infubinol", "Ketapril", "Naftisol", "Placebo", "Propriva", "Ramicane", "Stelasyn", "Zoniferol"],rotation="vertical")

plt.xlim(-0.75, len(x_axis)-.25)
plt.ylim(0, max(plot_list)+20)

plt.title("Number of Mice per Treatment")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")

plt.savefig("PyBar.png")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
group_by_gender = merged_df.groupby(["Mouse ID","Sex"])
gender_df = pd.DataFrame(group_by_gender.size())
mice_gender = pd.DataFrame(gender_df.groupby(["Sex"]).count())
mice_gender.columns = ["Total Count"]

colors = ["orange", "blue"]
explode = (0, 0)
plot = mice_gender.plot.pie(y="Total Count", figsize=(5,5), explode = explode, colors = colors, autopct="%1.1f%%", shadow=True, startangle=180)

plt.title("Male vs Female Mouse Population")
plt.ylabel("Sex")
plt.axis("equal")

plt.savefig("PieChart")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = ["Female","Male"]
sizes = [49.8,50.2]
colors = ["orange", "blue"]
explode = (0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=180)

plt.title("Male vs Female Mouse Population")
plt.ylabel("Sex")
plt.axis("equal")

plt.savefig("PyPie.png")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
Cap_df = merged_df.loc[merged_df["Drug Regimen"] == "Capomulin",:]
Ram_df = merged_df.loc[merged_df["Drug Regimen"] == "Ramicane", :]
Inf_df = merged_df.loc[merged_df["Drug Regimen"] == "Infubinol", :]
Cef_df = merged_df.loc[merged_df["Drug Regimen"] == "Ceftamin", :]

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
Cap_last = Cap_df.groupby("Mouse ID").max()["Timepoint"]
Cap_last_vol = pd.DataFrame(Cap_last)
Cap_last_merge = pd.merge(Cap_last_vol, merged_df, on=("Mouse ID","Timepoint"),how="left")
Cap_last_merge.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     b128         45    Capomulin  Female           9          22
# 1     b742         45    Capomulin    Male           7          21
# 2     f966         20    Capomulin    Male          16          17
# 3     g288         45    Capomulin    Male           3          19
# 4     g316         45    Capomulin  Female          22          22
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           30.485985                 0
# 3           37.074024                 1
# 4           40.159220                 2

# %%
# Put treatments into a list for for loop (and later for plot labels)
Cap_tumors = Cap_last_merge["Tumor Volume (mm3)"]

# Create empty list to fill with tumor vol data (for plotting)
quartiles = Cap_tumors.quantile([.25,.5,.75])

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Locate the rows which contain mice on each drug and get the tumor volumes
# add subset 
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

# Determine outliers using upper and lower bounds
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Capomulin potential outliers could be values below {lower_bound} and above {upper_bound} could be outliers.")
# Out:
# Capomulin potential outliers could be values below 20.70456164999999 and above 51.83201549 could be outliers.

# %%
Ram_last = Ram_df.groupby("Mouse ID").max()["Timepoint"]
Ram_last_vol = pd.DataFrame(Ram_last)
Ram_last_merge = pd.merge(Ram_last_vol, merged_df, on=("Mouse ID","Timepoint"),how="left")
Ram_last_merge.head()

Ram_tumors = Ram_last_merge["Tumor Volume (mm3)"]

quartiles =Ram_tumors.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f"Ramicane potential outliers could be values below {lower_bound} and above {upper_bound} could be outliers.")
# Out:
# Ramicane potential outliers could be values below 17.912664470000003 and above 54.30681135 could be outliers.

# %%
Inf_last = Inf_df.groupby("Mouse ID").max()["Timepoint"]
Inf_last_vol = pd.DataFrame(Inf_last)
Inf_last_merge = pd.merge(Inf_last_vol, merged_df, on=("Mouse ID","Timepoint"),how="left")
Inf_last_merge.head()

Inf_tumors = Inf_last_merge["Tumor Volume (mm3)"]

quartiles =Inf_tumors.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f"Infubinol potential outliers could be values below {lower_bound} and above {upper_bound} could be outliers.")
# Out:
# Infubinol potential outliers could be values below 36.83290494999999 and above 82.74144559000001 could be outliers.

# %%
Cef_last = Cef_df.groupby("Mouse ID").max()["Timepoint"]
Cef_last_vol = pd.DataFrame(Cef_last)
Cef_last_merge = pd.merge(Cef_last_vol, merged_df, on=("Mouse ID","Timepoint"),how="left")
Cef_last_merge.head()

Cef_tumors = Cef_last_merge["Tumor Volume (mm3)"]

quartiles =Cef_tumors.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f"Ceftamin potential outliers could be values below {lower_bound} and above {upper_bound} could be outliers.")
# Out:
# Ceftamin potential outliers could be values below 25.355449580000002 and above 87.66645829999999 could be outliers.

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
data = [Cap_tumors, Ram_tumors, Inf_tumors, Cef_tumors]

fig1, ax1 = plt.subplots()
ax1.set_title("Distrubution of The Tumor Volume")
ax1.set_ylabel("Final Tumor Volume (mm3)")
ax1.set_xlabel("Drug Regimen")

ax1.boxplot(data, labels=["Capomulin","Ramicane","Infubinol","Ceftamin",])

plt.savefig("BoxPlot.png")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
Cap_df = merged_df.loc[merged_df["Drug Regimen"] == "Capomulin",:]
xpoints = Cap_df.loc[Cap_df["Mouse ID"] == "l509",:]["Timepoint"]
ypoints = Cap_df.loc[Cap_df["Mouse ID"] == "l509",:]["Tumor Volume (mm3)"]

plt.title("Capomulin treatmeant for mouse l509")
plt.plot(xpoints, ypoints,linewidth=3, markersize=8)
plt.xlabel("Timepoint (Days)")
plt.ylabel("Tumor Volume (mm3)")

plt.savefig("LinePlot.png")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

Cap_mean =Cap_df.groupby(["Mouse ID"]).mean()

plt.scatter(Cap_mean["Weight (g)"],Cap_mean["Tumor Volume (mm3)"],marker="o", edgecolors="blue",
            s=Cap_mean['Weight (g)'], alpha=0.75)
plt.title("Tumor Volume vs. Mouse Weight Versus")
plt.xlabel("Weight (g)")
plt.ylabel("Averag Tumor Volume (mm3)")


plt.savefig("ScatterPlot.png")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
correlation=st.pearsonr(Cap_mean["Weight (g)"],Cap_mean["Tumor Volume (mm3)"] )
print(f"The correlation between mouse weight and average tumor volume is {round(correlation[0],2)}")
# Out:
# The correlation between mouse weight and average tumor volume is 0.84

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

x_values = Cap_mean["Weight (g)"]
y_values = Cap_mean["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()
